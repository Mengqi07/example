# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import geopandas as gpd
from shapely.geometry import shape

from urllib.parse import urlencode
import urllib.request, json 

import matplotlib.pyplot as plt
import seaborn as sns # visualization styling package
# %matplotlib inline 

import requests
import json

# %%
Client ID
ZvEtzNp2M4JkyJi5aInWQw

API Key
A1494GxC2qJ4HowdLuqAaWstz3Rk2AhGdZhR2q6nXJhZl28uXAVVbEL5dJmSTjBDee6vuS2swWby2RSz07Z6MqOm1WFHp7Q2cgPUQiwbahhuyfzWf1f0Dg_SfHHCX3Yx

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url1 = 'https://api.yelp.com/v3/businesses/search'
params1 = {'location':"New York City",'limit':"50"}
req1 = requests.get(url1, params = params1, headers = headers)
reqs1 = json.loads(req1.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params2 = {'location':"New York City", "offset": '100','limit':"50"}
req2 = requests.get(url, params = params2, headers = headers)
reqs2 = json.loads(req3.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params3 = {'location':"New York City", "offset": '100','limit':"50"}
req3 = requests.get(url, params = params3, headers = headers)
reqs3 = json.loads(req3.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params4 = {'location':"New York City", "offset": '150','limit':"50"}
req4 = requests.get(url, params = params4, headers = headers)
reqs4 = json.loads(req4.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params5 = {'location':"New York City", "offset": '200','limit':"50"}
req5 = requests.get(url, params = params5, headers = headers)
reqs5 = json.loads(req5.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params6 = {'location':"New York City", "offset": '250','limit':"50"}
req6 = requests.get(url, params = params6, headers = headers)
reqs6 = json.loads(req6.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params7 = {'location':"New York City","offset": '300','limit':"50"}
req7 = requests.get(url, params = params7, headers = headers)
reqs7 = json.loads(req7.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params8 = {'location':"New York City", "offset": '350','limit':"50"}
req8 = requests.get(url, params = params8, headers = headers)
reqs8 = json.loads(req8.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params9 = {'location':"New York City", "offset": '400','limit':"50"}
req9 = requests.get(url, params = params9, headers = headers)
reqs9 = json.loads(req9.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params10 = {'location':"New York City","offset": '450','limit':"50"}
req10 = requests.get(url, params = params10, headers = headers)
reqs10 = json.loads(req10.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params11 = {'location':"New York City", "offset": '500','limit':"50"}
req11 = requests.get(url, params = params11, headers = headers)
reqs11 = json.loads(req11.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params12 = {'location':"New York City", "offset": '550','limit':"50"}
req12 = requests.get(url, params = params12, headers = headers)
reqs12 = json.loads(req12.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params13 = {'location':"New York City", "offset": '600','limit':"50"}
req13 = requests.get(url, params = params13, headers = headers)
reqs13 = json.loads(req13.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params14 = {'location':"New York City","offset": '650','limit':"50"}
req14 = requests.get(url, params = params14, headers = headers)
reqs14 = json.loads(req14.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params15 = {'location':"New York City", "offset": '700','limit':"50"}
req15 = requests.get(url, params = params15, headers = headers)
reqs15 = json.loads(req15.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params16 = {'location':"New York City", "offset": '750','limit':"50"}
req16 = requests.get(url, params = params16, headers = headers)
reqs16 = json.loads(req16.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params17 = {'location':"New York City", "offset": '800','limit':"50"}
req17 = requests.get(url, params = params17, headers = headers)
reqs17 = json.loads(req17.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params18 = {'location':"New York City","offset": '850','limit':"50"}
req18 = requests.get(url, params = params18, headers = headers)
reqs18 = json.loads(req18.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params19 = {'location':"New York City", "offset": '900','limit':"50"}
req19 = requests.get(url, params = params19, headers = headers)
reqs19 = json.loads(req19.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params20 = {'location':"New York City", "offset": '950','limit':"50"}
req20 = requests.get(url, params = params20, headers = headers)
reqs20 = json.loads(req20.text)

# %%
reqs20['businesses']
# Out:
# [{'id': 'KaBw8UEm8uZTV6YLsshYrQ',
#   'alias': 'pocha-32-new-york',
#   'name': 'Pocha 32',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OyKoVf4QMel7EViErNRzHw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pocha-32-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 1497,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.747524574399, 'longitude': -73.9862626791},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '15 W 32nd St',
#    'address2': 'Fl 2',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['15 W 32nd St', 'Fl 2', 'New York, NY 10001']},
#   'phone': '+12122791876',
#   'display_phone': '(212) 279-1876',
#   'distance': 4748.056316776482},
#  {'id': 'RThvexVhZQ8KA6JAr0UkCQ',
#   'alias': 'casa-adela-new-york',
#   'name': 'Casa Adela',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CrSVEHHLE8JhciwZAEZ-aQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/casa-adela-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 467,
#   'categories': [{'alias': 'latin', 'title': 'Latin American'},
#    {'alias': 'puertorican', 'title': 'Puerto Rican'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72264, 'longitude': -73.97973},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '66 Ave C',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['66 Ave C', 'New York, NY 10009']},
#   'phone': '+12124731882',
#   'display_phone': '(212) 473-1882',
#   'distance': 2272.953920249339},
#  {'id': 'zwOAiVT4pAmpNGXzj-t5MA',
#   'alias': 'lilia-brooklyn',
#   'name': 'Lilia',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qQYC0L1Gr2f_KmLIpmjxdg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lilia-brooklyn?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 836,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.71757, 'longitude': -73.95236},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '567 Union Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['567 Union Ave', 'Brooklyn, NY 11211']},
#   'phone': '+17185763095',
#   'display_phone': '(718) 576-3095',
#   'distance': 3776.4789584058713},
#  {'id': 'WFOaud0jlpXQ9aEecipUqg',
#   'alias': 'las-ramblas-new-york',
#   'name': 'Las Ramblas',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tFnuD6tpdvAEQeBNqNxr3w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/las-ramblas-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 720,
#   'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.731958, 'longitude': -74.0015486},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '170 W 4th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['170 W 4th St', 'New York, NY 10014']},
#   'phone': '+16464157924',
#   'display_phone': '(646) 415-7924',
#   'distance': 3018.8444501058625},
#  {'id': 'RW-v9cm9rQZS9cSihuXfvw',
#   'alias': 'brandy-library-new-york',
#   'name': 'Brandy Library',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/745pwDw2lJ7gENHEQlqwFA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/brandy-library-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 605,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'lounges', 'title': 'Lounges'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.720073, 'longitude': -74.007227},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$$',
#   'location': {'address1': '25 N Moore St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['25 N Moore St', 'New York, NY 10013']},
#   'phone': '+12122265545',
#   'display_phone': '(212) 226-5545',
#   'distance': 1958.0842495882698},
#  {'id': 'rCpO-kMHljieU0geK0RJQw',
#   'alias': 'noreetuh-new-york',
#   'name': 'Noreetuh',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PoqPAHXhTGUk9DeFimdl6Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/noreetuh-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 437,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'hawaiian', 'title': 'Hawaiian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.727275, 'longitude': -73.985221},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '128 1st Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['128 1st Ave', 'New York, NY 10009']},
#   'phone': '+16468923050',
#   'display_phone': '(646) 892-3050',
#   'distance': 2545.6431572121646},
#  {'id': 'jzQNE09rRKz8Ou-bEdEY1Q',
#   'alias': 'the-grey-dog-nolita-new-york-3',
#   'name': 'The Grey Dog - Nolita',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kbRn1m93T44sx3mKKXQWkw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-grey-dog-nolita-new-york-3?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 600,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7229699, 'longitude': -73.99576},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '244 Mulberry St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['244 Mulberry St', 'New York, NY 10012']},
#   'phone': '+12129661060',
#   'display_phone': '(212) 966-1060',
#   'distance': 1949.6090161894615},
#  {'id': 'iQB37FNqD_G5_QMrp9ovnw',
#   'alias': 'jadis-new-york',
#   'name': 'Jadis',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fkpYUCwqIP-E3kBh2uJgPA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jadis-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 491,
#   'categories': [{'alias': 'french', 'title': 'French'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7210234741789,
#    'longitude': -73.9910054106201},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '42 Rivington St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['42 Rivington St', 'New York, NY 10002']},
#   'phone': '+12122541675',
#   'display_phone': '(212) 254-1675',
#   'distance': 1754.284879719958},
#  {'id': '2RbBg1CIxBZAc2MQPdxkcA',
#   'alias': 'lillies-victorian-establishment-new-york',
#   'name': "Lillie's Victorian Establishment",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sBLOuDpQfuxrjS8eG5RGnA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lillies-victorian-establishment-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 1057,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'british', 'title': 'British'},
#    {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.737661, 'longitude': -73.991113},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '13 E 17th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['13 E 17th St', 'New York, NY 10003']},
#   'phone': '+12123371970',
#   'display_phone': '(212) 337-1970',
#   'distance': 3592.2783333741954},
#  {'id': 'nZhpUWlVygHyIxvLCf_TvQ',
#   'alias': 'blue-stripes-cacao-shop-new-york',
#   'name': 'Blue Stripes Cacao Shop',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TuEATQzwY97UjIJQziunRg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blue-stripes-cacao-shop-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 336,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'chocolate', 'title': 'Chocolatiers & Shops'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.73464, 'longitude': -73.9929},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '28 East 13th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['28 East 13th St', 'New York, NY 10003']},
#   'phone': '+19172658737',
#   'display_phone': '(917) 265-8737',
#   'distance': 3247.834596024704},
#  {'id': 'jZZMmT7Mk3S-fNjXcq3Ksg',
#   'alias': 'devocion-williamsburg',
#   'name': 'Devocion',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/33rJ0M41qXFWuQOIF382Ow/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/devocion-williamsburg?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 445,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.716083, 'longitude': -73.964752},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '69 Grand St',
#    'address2': None,
#    'address3': '',
#    'city': 'Williamsburg',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['69 Grand St', 'Williamsburg, NY 11249']},
#   'phone': '+17182856180',
#   'display_phone': '(718) 285-6180',
#   'distance': 2762.7656443327546},
#  {'id': 'UBCNhz-TSvBP3zo5PjFWrQ',
#   'alias': 'aureole-at-home-new-york',
#   'name': 'Aureole at Home',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/c8v2CRAc7JevMm7YgNW5qQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/aureole-at-home-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 895,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7555870079476,
#    'longitude': -73.9852531626821},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '135 W 42nd St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10036',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['135 W 42nd St', 'New York, NY 10036']},
#   'phone': '+12123191660',
#   'display_phone': '(212) 319-1660',
#   'distance': 5627.339242447702},
#  {'id': 'HUlbrPvAr6sXuBfp5z1MWA',
#   'alias': 'urban-backyard-new-york',
#   'name': 'Urban Backyard',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uEuwZMLBWP4VhkkV7RFdcw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/urban-backyard-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 158,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.72077, 'longitude': -73.99646},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '180 Mulberry St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['180 Mulberry St', 'New York, NY 10012']},
#   'phone': '+16466929957',
#   'display_phone': '(646) 692-9957',
#   'distance': 1716.018342303412},
#  {'id': '85x3dZCMBj4rJ2LAdW-wFg',
#   'alias': 'magnolia-bakery-west-village-new-york',
#   'name': 'Magnolia Bakery West Village',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fqN9-uf9O3qyY8q5qj8ENA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/magnolia-bakery-west-village-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 2403,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'cupcakes', 'title': 'Cupcakes'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.73589, 'longitude': -74.00498},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '401 Bleecker St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['401 Bleecker St', 'New York, NY 10014']},
#   'phone': '+12124622572',
#   'display_phone': '(212) 462-2572',
#   'distance': 3501.4198143415374},
#  {'id': 'm2_ZNFos5ugAwe8ft8eaEw',
#   'alias': 'eim-khao-mun-kai-elmhurst-elmhurst',
#   'name': 'Eim Khao Mun Kai Elmhurst',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JqeuGqrZxCPGVowAEs8XFQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/eim-khao-mun-kai-elmhurst-elmhurst?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 449,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'hainan', 'title': 'Hainan'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7429414097644,
#    'longitude': -73.8832733356575},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '81-32 Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'Elmhurst',
#    'zip_code': '11373',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['81-32 Broadway', 'Elmhurst, NY 11373']},
#   'phone': '+17184247156',
#   'display_phone': '(718) 424-7156',
#   'distance': 10242.660253694328},
#  {'id': '83BXSwE0166sObnXLUE4bQ',
#   'alias': 'land-new-york',
#   'name': 'Land',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ptDV_QtdeLeSvBZs-tTqWA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/land-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 1058,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.78497, 'longitude': -73.9772182},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '450 Amsterdam Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10024',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['450 Amsterdam Ave', 'New York, NY 10024']},
#   'phone': '+12125018121',
#   'display_phone': '(212) 501-8121',
#   'distance': 8959.014790043642},
#  {'id': 'BA6wd1pZTVu1DmrtiyTs8g',
#   'alias': 'raouls-restaurant-new-york',
#   'name': "Raoul's Restaurant",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5DpYOnd6N-el26VILVbvIg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/raouls-restaurant-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 506,
#   'categories': [{'alias': 'french', 'title': 'French'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72615, 'longitude': -74.00216},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '180 Prince St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['180 Prince St', 'New York, NY 10012']},
#   'phone': '+12129663518',
#   'display_phone': '(212) 966-3518',
#   'distance': 2397.616235487115},
#  {'id': 'UuY1QCxWybMF0IMxAYG06w',
#   'alias': 'emmy-squared-brooklyn-brooklyn-2',
#   'name': 'Emmy Squared - Brooklyn',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5CQoV1JqcMM9rt_-wYBYzg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/emmy-squared-brooklyn-brooklyn-2?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 631,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.712168, 'longitude': -73.955707},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '364 Grand St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['364 Grand St', 'Brooklyn, NY 11211']},
#   'phone': '+17183604535',
#   'display_phone': '(718) 360-4535',
#   'distance': 3337.371448778803},
#  {'id': 'eIPiRkf6KCo9A9Ok-Nr_ow',
#   'alias': 'miss-korea-bbq-new-york',
#   'name': 'Miss KOREA BBQ',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Aep13M2z7VkF3Ub0bCMoCw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/miss-korea-bbq-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 1770,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.747452, 'longitude': -73.986336},
#   'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '10 W 32nd St',
#    'address2': '1st, 2nd & Fl 3',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['10 W 32nd St',
#     '1st, 2nd & Fl 3',
#     'New York, NY 10001']},
#   'phone': '+12125944963',
#   'display_phone': '(212) 594-4963',
#   'distance': 4718.858059205753},
#  {'id': 'nsAU6F2vmdnphmfIa_RuWg',
#   'alias': 'mables-smokehouse-and-banquet-hall-brooklyn-6',
#   'name': "Mable's Smokehouse & Banquet Hall",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OS2cqRCWCOioXnpLo-yeHg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mables-smokehouse-and-banquet-hall-brooklyn-6?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 863,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7211890204726,
#    'longitude': -73.9570004492998},
#   'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '44 Berry St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['44 Berry St', 'Brooklyn, NY 11249']},
#   'phone': '+17182186655',
#   'display_phone': '(718) 218-6655',
#   'distance': 3597.829928403173},
#  {'id': 'OOoua3Q6PfqtImv3DjdcWw',
#   'alias': 'parlay-sunset-park',
#   'name': 'Parlay',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kiBwiW7tuOkECU2jCDavGg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/parlay-sunset-park?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 409,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.6464, 'longitude': -73.99862},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '4024 8th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Sunset Park',
#    'zip_code': '11232',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['4024 8th Ave', 'Sunset Park, NY 11232']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 6578.151806385639},
#  {'id': '7YJxZAvMxB-oVZfHAuvBmw',
#   'alias': 'lakruwana-restaurant-staten-island-2',
#   'name': 'Lakruwana Restaurant ',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kuerfRTidkJmKHmdoE0pyw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lakruwana-restaurant-staten-island-2?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 327,
#   'categories': [{'alias': 'srilankan', 'title': 'Sri Lankan'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.62571, 'longitude': -74.075373},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '668 Bay St',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10304',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['668 Bay St', 'Staten Island, NY 10304']},
#   'phone': '+13478576619',
#   'display_phone': '(347) 857-6619',
#   'distance': 11197.065298631001},
#  {'id': '6FZf17rNThWKoF4EU18wnw',
#   'alias': 'yakiniku-futago-new-york',
#   'name': 'Yakiniku Futago',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/e4EIIUdPpu-64PdxuOFwkQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/yakiniku-futago-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 347,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.738851870947, 'longitude': -73.9941236398979},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$$',
#   'location': {'address1': '37 W 17th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['37 W 17th St', 'New York, NY 10011']},
#   'phone': '+12126200225',
#   'display_phone': '(212) 620-0225',
#   'distance': 3714.713004612417},
#  {'id': 'Z-hDHjP4Eza6BA4G97tzVA',
#   'alias': 'blvd-bistro-new-york',
#   'name': 'BLVD Bistro',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SRmEfV9JhCcHQdPaACxGtA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blvd-bistro-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 910,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'soulfood', 'title': 'Soul Food'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.80438, 'longitude': -73.9558},
#   'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '2149 Frederick Douglass Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10026',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2149 Frederick Douglass Blvd', 'New York, NY 10026']},
#   'phone': '+12126786200',
#   'display_phone': '(212) 678-6200',
#   'distance': 11468.226070653858},
#  {'id': 'izRJeBfDQYJmd6ibIQ6Mfg',
#   'alias': 'mughlai-indian-cuisine-new-york-4',
#   'name': 'Mughlai Indian Cuisine',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/43GcjkkthQQjUHK4-moyvg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mughlai-indian-cuisine-new-york-4?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 493,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.78002, 'longitude': -73.94978},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1724 2nd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10128',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1724 2nd Ave', 'New York, NY 10128']},
#   'phone': '+12127226262',
#   'display_phone': '(212) 722-6262',
#   'distance': 9100.989030946266},
#  {'id': 'W5RSIwNKBa7k0jeAs5KDYg',
#   'alias': 'mei-jin-ramen-new-york',
#   'name': 'Mei Jin Ramen',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wZk0imvvGaHxDuYHk70qyQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mei-jin-ramen-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 713,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.775049, 'longitude': -73.953553},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1574 2nd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10028',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1574 2nd Ave', 'New York, NY 10028']},
#   'phone': '+12123272800',
#   'display_phone': '(212) 327-2800',
#   'distance': 8466.563652243987},
#  {'id': '4GBqDgTYsV7owGzNMyAFKA',
#   'alias': 'sullivan-street-bakery-new-york-3',
#   'name': 'Sullivan Street Bakery',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9IqTUcD62P3ziCRpCel3dA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sullivan-street-bakery-new-york-3?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 506,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.76366, 'longitude': -73.994716},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '533 W 47th St',
#    'address2': None,
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10036',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['533 W 47th St', 'New York, NY 10036']},
#   'phone': '+12122655580',
#   'display_phone': '(212) 265-5580',
#   'distance': 6473.318564773586},
#  {'id': 'Duh9gmBVHodHKQaQqsyZcg',
#   'alias': 'moms-kitchen-and-bar-astoria',
#   'name': "Mom's Kitchen & Bar",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bz7TPVap1l0bfhJnfM1Xaw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/moms-kitchen-and-bar-astoria?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 750,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.76372, 'longitude': -73.92158},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '33-01 31st Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Astoria',
#    'zip_code': '11102',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['33-01 31st Ave', 'Astoria, NY 11102']},
#   'phone': '+17182670142',
#   'display_phone': '(718) 267-0142',
#   'distance': 8905.717620871108},
#  {'id': 'XKWvRI7WI4LotDLUboUUGA',
#   'alias': 'barney-greengrass-new-york',
#   'name': 'Barney Greengrass',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/je84DKJxPdEQq9QFzS3eWw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/barney-greengrass-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 757,
#   'categories': [{'alias': 'gourmet', 'title': 'Specialty Food'},
#    {'alias': 'delis', 'title': 'Delis'},
#    {'alias': 'bagels', 'title': 'Bagels'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7879308300971,
#    'longitude': -73.9745054748688},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '541 Amsterdam Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10024',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['541 Amsterdam Ave', 'New York, NY 10024']},
#   'phone': '+12127244707',
#   'display_phone': '(212) 724-4707',
#   'distance': 9322.258112599642},
#  {'id': 'U-VF6WSAWTN_6iDpWd5kqw',
#   'alias': 'v-nam-cafe-new-york',
#   'name': 'V-Nam Cafe',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c4yVRtmP_szhblwFI-ghEQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/v-nam-cafe-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 487,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7233696141088,
#    'longitude': -73.9881201811982},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '20 1st Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['20 1st Ave', 'New York, NY 10003']},
#   'phone': '+12127806020',
#   'display_phone': '(212) 780-6020',
#   'distance': 2059.9252415748697},
#  {'id': 'wRHUJ69-f4CiV5BRY72mUg',
#   'alias': 'aqua-boil-new-york-2',
#   'name': 'Aqua Boil',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wREsz4nOI5oGdYrRiOG1uA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/aqua-boil-new-york-2?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 313,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.763702, 'longitude': -73.988386},
#   'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '750 9th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['750 9th Ave', 'New York, NY 10019']},
#   'phone': '+12124647428',
#   'display_phone': '(212) 464-7428',
#   'distance': 6497.896610888184},
#  {'id': 'SCQvI5pAJmD-OMm37kkS6Q',
#   'alias': 'dorado-tacos-and-quesadillas-new-york-3',
#   'name': 'DORADO Tacos & Quesadillas',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hnzUM5cHSTuCyh2WtsMZDA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dorado-tacos-and-quesadillas-new-york-3?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 651,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.73396, 'longitude': -73.99312},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '28 E 12th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['28 E 12th St', 'New York, NY 10003']},
#   'phone': '+12126270900',
#   'display_phone': '(212) 627-0900',
#   'distance': 3169.948723705394},
#  {'id': 'LRgB2kEKtBxqIxNksTO_PQ',
#   'alias': 'patrizias-williamsburg-brooklyn',
#   'name': "Patrizia's - Williamsburg",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FeqJGZwDuZFymjWDtng60w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/patrizias-williamsburg-brooklyn?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 662,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7109154314181,
#    'longitude': -73.9673637711639},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '35 Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['35 Broadway', 'Brooklyn, NY 11249']},
#   'phone': '+17182189272',
#   'display_phone': '(718) 218-9272',
#   'distance': 2349.983905012418},
#  {'id': 'cO9E0n9ulzJ6eZ4TKrFx1A',
#   'alias': 'mille-feuille-bakery-new-york-2',
#   'name': 'Mille-Feuille Bakery',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tF46aDSEYYoEcbXAl3WHIw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mille-feuille-bakery-new-york-2?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 477,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72933, 'longitude': -73.99808},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '552 Laguardia Pl',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['552 Laguardia Pl', 'New York, NY 10012']},
#   'phone': '+12125334698',
#   'display_phone': '(212) 533-4698',
#   'distance': 2657.8473641828227},
#  {'id': 'ulKoAGcGOdsXgr0o_l6avA',
#   'alias': 'ruths-chris-steak-house-new-york-5',
#   'name': "Ruth's Chris Steak House",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BVJgcZNd9y7zFzgBgxiHRA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ruths-chris-steak-house-new-york-5?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 976,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7613252601449,
#    'longitude': -73.9822581410407},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '148 W 51st St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['148 W 51st St', 'New York, NY 10019']},
#   'phone': '+12122459600',
#   'display_phone': '(212) 245-9600',
#   'distance': 6295.81224813984},
#  {'id': 'IKB1DhFCLFY98mTt_l6u2A',
#   'alias': 'stumptown-coffee-roasters-new-york-2',
#   'name': 'Stumptown Coffee Roasters',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AQJWHI42-wg8ioaH1fh3cQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/stumptown-coffee-roasters-new-york-2?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 435,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7328193931365,
#    'longitude': -73.9979619990999},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '30 W 8th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['30 W 8th St', 'New York, NY 10011']},
#   'phone': '+13474147802',
#   'display_phone': '(347) 414-7802',
#   'distance': 3059.568496199233},
#  {'id': 'AawLwOYZwMf_9wkShExfuw',
#   'alias': 'sanfords-astoria-astoria',
#   'name': 'Sanfords Astoria',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dQwdngc4tQsPpZtUMGvQcQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sanfords-astoria-astoria?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 883,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'whiskeybars', 'title': 'Whiskey Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7623, 'longitude': -73.92555},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '30-13 Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'Astoria',
#    'zip_code': '11106',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['30-13 Broadway', 'Astoria, NY 11106']},
#   'phone': '+17189329569',
#   'display_phone': '(718) 932-9569',
#   'distance': 8574.096783834835},
#  {'id': 'd_rQ-nVpY6Z5C722Q5wpog',
#   'alias': 'defontes-brooklyn',
#   'name': 'Defontes',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Yt11r7xeLy1QGXhpUgf7Ng/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/defontes-brooklyn?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 348,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.6789444357833,
#    'longitude': -74.0053691263199},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '379 Columbia St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11231',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['379 Columbia St', 'Brooklyn, NY 11231']},
#   'phone': '+17186258052',
#   'display_phone': '(718) 625-8052',
#   'distance': 3091.1342477657317},
#  {'id': 'oJZq1JmKalXXjqWRKfIjwA',
#   'alias': 'sushi-azabu-new-york',
#   'name': 'Sushi Azabu',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xbsZaYWdTWzVktt9EG4txw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sushi-azabu-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 435,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7222930324682,
#    'longitude': -74.0098838048935},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$$',
#   'location': {'address1': '428 Greenwich St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['428 Greenwich St', 'New York, NY 10013']},
#   'phone': '+12122740428',
#   'display_phone': '(212) 274-0428',
#   'distance': 2288.3160701734155},
#  {'id': 'z5EpI39omxW6aK_X2uHi8A',
#   'alias': 'lobster-joint-brooklyn',
#   'name': 'Lobster Joint',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mqStg2ixrTyqOPTQWnqaFA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lobster-joint-brooklyn?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 661,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7354, 'longitude': -73.95528},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1073 Manhattan Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1073 Manhattan Ave', 'Brooklyn, NY 11222']},
#   'phone': '+17183898990',
#   'display_phone': '(718) 389-8990',
#   'distance': 4676.725389301891},
#  {'id': '4rWJGwb3rjDoZHA0AECa5A',
#   'alias': 'melbas-restaurant-new-york-2',
#   'name': "Melba's Restaurant",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-Osj3DK7Geyvx23aFhwXfQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/melbas-restaurant-new-york-2?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 1145,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'soulfood', 'title': 'Soul Food'},
#    {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.8031468838453,
#    'longitude': -73.9565069228411},
#   'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '300 W 114th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10026',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['300 W 114th St', 'New York, NY 10026']},
#   'phone': '+12128647777',
#   'display_phone': '(212) 864-7777',
#   'distance': 11314.409816132875},
#  {'id': '5mOOEmKa5H98m9HT5dam1g',
#   'alias': 'oculus-new-york',
#   'name': 'Oculus',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BTBMvzl5ClPuDasXfqTYUQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/oculus-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 302,
#   'categories': [{'alias': 'landmarks',
#     'title': 'Landmarks & Historical Buildings'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7115051, 'longitude': -74.011386},
#   'transactions': [],
#   'location': {'address1': 'World Trade Center Transportation Hub',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10006',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['World Trade Center Transportation Hub',
#     'New York, NY 10006']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 1590.5513301298402},
#  {'id': 'SZXOfQbLyF3C5GwYBj6VvA',
#   'alias': 'saltwater-coffee-new-york',
#   'name': 'Saltwater Coffee',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cdBBTyVhiBft09uTwGStcw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/saltwater-coffee-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 218,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7304578, 'longitude': -73.9839175},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '345 E 12th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['345 E 12th St', 'New York, NY 10003']},
#   'phone': '+19178812245',
#   'display_phone': '(917) 881-2245',
#   'distance': 2915.5320769059854},
#  {'id': 'VzHdgvEv9bx9RVrNbhsmQw',
#   'alias': 'little-pie-company-new-york',
#   'name': 'Little Pie Company',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZXbM-XeC2OOI53WqJZ0hhg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/little-pie-company-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 706,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.75949, 'longitude': -73.99332},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '424 W 43rd St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10036',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['424 W 43rd St', 'New York, NY 10036']},
#   'phone': '+18778727437',
#   'display_phone': '(877) 872-7437',
#   'distance': 6006.524799250135},
#  {'id': 'vec8jeVbbSGzVlStl0Xp_Q',
#   'alias': 'chikarashi-new-york',
#   'name': 'Chikarashi',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dXGsF2g2RWKL1cObKBv4pw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chikarashi-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 491,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'hawaiian', 'title': 'Hawaiian'},
#    {'alias': 'poke', 'title': 'Poke'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.71787, 'longitude': -73.99948},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '227 Canal St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['227 Canal St', 'New York, NY 10013']},
#   'phone': '+16466495965',
#   'display_phone': '(646) 649-5965',
#   'distance': 1456.2531265296136},
#  {'id': 'qpkFmGyvbZv-g2fbwyNQUg',
#   'alias': 'bowery-meat-company-new-york',
#   'name': 'Bowery Meat Company',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1APX7RIBkKwQ80r7jT2vJg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bowery-meat-company-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 507,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72453, 'longitude': -73.9917876},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '9 E 1st St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['9 E 1st St', 'New York, NY 10003']},
#   'phone': '+12124605255',
#   'display_phone': '(212) 460-5255',
#   'distance': 2136.248529912733},
#  {'id': 'rd0VGG_d_qNp_aBW_HJM4w',
#   'alias': 'third-rail-coffee-new-york',
#   'name': 'Third Rail Coffee',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vxOIeyZiQSVsB-h8-j1UWg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/third-rail-coffee-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 473,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72994, 'longitude': -73.99959},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '240 Sullivan St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['240 Sullivan St', 'New York, NY 10012']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 2765.2849385347295},
#  {'id': '8NVN6Nldm7AGoGaABBZMRw',
#   'alias': 'izakaya-nomad-new-york',
#   'name': 'Izakaya NoMad',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/s3qyS_ZDM3WXeqXjLNFPCA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/izakaya-nomad-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 678,
#   'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#    {'alias': 'izakaya', 'title': 'Izakaya'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.74409, 'longitude': -73.98945},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '13 W 26th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10010',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['13 W 26th St', 'New York, NY 10010']},
#   'phone': '+12122136258',
#   'display_phone': '(212) 213-6258',
#   'distance': 4324.0303176280795},
#  {'id': 'LA7riLKSg-aBLgTY4fT8GQ',
#   'alias': 'sarabeths-central-park-new-york',
#   'name': 'Sarabeths - Central Park',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Wtz5mF63UW1tIbIKrWwO_g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sarabeths-central-park-new-york?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 1817,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.765158, 'longitude': -73.975724},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '40 Central Park S',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['40 Central Park S', 'New York, NY 10019']},
#   'phone': '+12128265959',
#   'display_phone': '(212) 826-5959',
#   'distance': 6821.63336223817},
#  {'id': 'xyBTcpnkIxV2h0AKU0pP0Q',
#   'alias': 'thái-son-new-york-3',
#   'name': 'Thái Son',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kWEctCiG8nhoauEDbVyfqQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/th%C3%A1i-son-new-york-3?adjust_creative=MbJnmyEh2buOoKQVg0YPQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=MbJnmyEh2buOoKQVg0YPQw',
#   'review_count': 875,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.71677, 'longitude': -73.9995},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '89 Baxter St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['89 Baxter St', 'New York, NY 10013']},
#   'phone': '+12127322822',
#   'display_phone': '(212) 732-2822',
#   'distance': 1335.3736318433362}]

# %%
for i in range(1,21,1):
    globals()['parsed%s' % i] = json.loads(globals()['req%s' % i].text)

# %%
for i in range(1,21,1):
    globals()['businesses%s' % i] = globals()['parsed%s' % i]["businesses"]

# %%
for i in range(1,21,1)
       name, rating, review_count,categories,address, latitude, longitude = [], [], [], [], [],[],[] 
for b in  globals()['businesses5']:
        name.append(b['name'])
        rating.append(b['rating'])
        address.append(b['location']['display_address'])
        latitude.append(b['coordinates']['latitude'])
        longitude.append(b['coordinates']['longitude'])
        review_count.append(b['review_count'])
        categories.append(b['categories'])
            
        globals()['df5'] = pd.DataFrame()
        globals()['df5']['name'] = name
        globals()['df5']['rating'] = rating
        globals()['df5']['review_count'] = review_count
        globals()['df5']['address'] = address
        globals()['df5']['latitude'] = latitude
        globals()['df5']['longitude'] = longitude
        globals()['df5']['category']= categories
df1
# Out:
#                                       name  rating  review_count  \
# 0                            Levain Bakery     4.5          8247
# 1                      Katz's Delicatessen     4.0         12464
# 2                                Ippudo NY     4.0         10007
# 3                           The Halal Guys     4.0          9520
# 4           The Metropolitan Museum of Art     4.5          2911
# 5                             Central Park     5.0          2495
# 6                             Bibble & Sip     4.5          4843
# 7                           Los Tacos No.1     4.5          3038
# 8                                 LoveMama     4.5          5131
# 9                      Prince Street Pizza     4.5          3718
# 10                     Best Bagel & Coffee     4.5          3346
# 11         Burger & Lobster - Flatiron NYC     4.0          5452
# 12                              Thai Villa     4.5          3467
# 13                         Gramercy Tavern     4.5          2931
# 14                           The High Line     4.5          2348
# 15                             Peter Luger     4.0          5797
# 16                          Doughnut Plant     4.5          3226
# 17   National September 11 Memorial Museum     4.5          1421
# 18           Clinton Street Baking Company     4.0          5109
# 19                             Shake Shack     4.0          5597
# 20                          Los Tacos No.1     4.5          1831
# 21                            Le Bernardin     4.5          2549
# 22                  Dominique Ansel Bakery     4.0          4566
# 23                             Taiyaki NYC     4.5          2907
# 24                         Brooklyn Bridge     4.5          1390
# 25                         Jacob's Pickles     4.0          4275
# 26                         Juliana's Pizza     4.5          2239
# 27                                Buddakan     4.0          4004
# 28                                  Amélie     4.5          2693
# 29                          Joe's Shanghai     4.0          6238
# 30                       Club A Steakhouse     4.5          2818
# 31                        Russ & Daughters     4.5          2252
# 32                         Eataly Flatiron     4.0          5638
# 33             Chinatown Ice Cream Factory     4.0          2794
# 34                                 Anytime     4.5          1421
# 35                         Ippudo Westside     4.0          3701
# 36                     Eleven Madison Park     4.5          2184
# 37                        Spot Dessert Bar     4.0          3014
# 38                        Lombardi's Pizza     4.0          6127
# 39    Del Frisco's Double Eagle Steakhouse     4.5          3013
# 40         Upstate Craft Beer & Oyster Bar     4.5          1873
# 41                  Grand Central Terminal     4.5          1400
# 42                                 Up Thai     4.5          2353
# 43                                Rubirosa     4.5          2285
# 44                      Top Thai Greenwich     4.5          1516
# 45                          Rice To Riches     4.0          3031
# 46                             ABC Kitchen     4.0          2975
# 47  Junior's Restaurant & Bakery - 45th St     4.0          4628
# 48                        Molly's Cupcakes     4.5          1677
# 49                The Museum of Modern Art     4.5          1990
#
#                                               address   latitude  longitude  \
# 0                 [167 W 74th St, New York, NY 10023]  40.779961 -73.980299
# 1              [205 E Houston St, New York, NY 10002]  40.722237 -73.987526
# 2                    [65 4th Ave, New York, NY 10003]  40.730920 -73.990150
# 3                     [W 53rd St, New York, NY 10019]  40.761861 -73.979306
# 4                  [1000 5th Ave, New York, NY 10028]  40.779449 -73.963245
# 5   [14 E 60th St, Central Park Conservancy, New Y...  40.782419 -73.965602
# 6                 [253 W 51st St, New York, NY 10019]  40.762820 -73.985180
# 7                    [75 9th Ave, New York, NY 10011]  40.742555 -74.006084
# 8                   [174 2nd Ave, New York, NY 10003]  40.730386 -73.986061
# 9                  [27 Prince St, New York, NY 10012]  40.722909 -73.994486
# 10                [225 W 35th St, New York, NY 10001]  40.752268 -73.991086
# 11                 [39 W 19th St, New York, NY 10011]  40.740070 -73.993440
# 12         [5 E 19th St, G Floor, New York, NY 10003]  40.739020 -73.990650
# 13                 [42 E 20th St, New York, NY 10003]  40.738440 -73.988250
# 14            [820 Washington St, New York, NY 10014]  40.739600 -74.008440
# 15                 [178 Broadway, Brooklyn, NY 11211]  40.709945 -73.962478
# 16                 [379 Grand St, New York, NY 10002]  40.716334 -73.988652
# 17             [180 Greenwich St, New York, NY 10007]  40.711430 -74.012481
# 18                 [4 Clinton St, New York, NY 10002]  40.721128 -73.983933
# 19  [E 23rd St Madison Avenue, Madison Square Park...  40.741732 -73.988185
# 20                [229 W 43rd St, New York, NY 10036]  40.757507 -73.987772
# 21  [155 W 51st St, The Equitable Bldg, New York, ...  40.761557 -73.981763
# 22                [189 Spring St, New York, NY 10012]  40.725220 -74.002910
# 23                [119 Baxter St, New York, NY 10013]  40.717890 -73.998800
# 24                [334 Furman St, Brooklyn, NY 11201]  40.705968 -73.996666
# 25            [509 Amsterdam Ave, New York, NY 10024]  40.786650 -73.975528
# 26             [19 Old Fulton St, Brooklyn, NY 11201]  40.702615 -73.993416
# 27                   [75 9th Ave, New York, NY 10011]  40.742276 -74.004800
# 28                  [22 W 8th St, New York, NY 10011]  40.732700 -73.997660
# 29                 [46 Bowery St, New York, NY 10013]  40.715661 -73.996701
# 30                [240 E 58th St, New York, NY 10022]  40.760060 -73.965570
# 31             [179 E Houston St, New York, NY 10002]  40.722589 -73.988283
# 32                  [200 5th Ave, New York, NY 10010]  40.741959 -73.989717
# 33                 [65 Bayard St, New York, NY 10013]  40.715452 -73.998180
# 34           [23 W 32nd St, Fl 3, New York, NY 10001]  40.747790 -73.986740
# 35                [321 W 51st St, New York, NY 10019]  40.763440 -73.986610
# 36               [11 Madison Ave, New York, NY 10010]  40.741691 -73.987207
# 37               [13 St Marks Pl, New York, NY 10003]  40.729390 -73.988920
# 38                 [32 Spring St, New York, NY 10012]  40.721593 -73.995596
# 39     [1221 Ave Of The Americas, New York, NY 10020]  40.759412 -73.982221
# 40                   [95 1st Ave, New York, NY 10003]  40.726373 -73.986557
# 41                 [89 E 42nd St, New York, NY 10017]  40.752793 -73.977165
# 42                 [1411 2nd Ave, New York, NY 10021]  40.769828 -73.957633
# 43              [235 Mulberry St, New York, NY 10012]  40.722766 -73.996233
# 44              [235 Sullivan St, New York, NY 10012]  40.729771 -73.999392
# 45                 [37 Spring St, New York, NY 10012]  40.721845 -73.995802
# 46                 [35 E 18th St, New York, NY 10003]  40.737832 -73.989649
# 47                [1515 Broadway, New York, NY 10036]  40.758266 -73.986540
# 48              [228 Bleecker St, New York, NY 10014]  40.730140 -74.002480
# 49              [11 West 53rd St, New York, NY 10019]  40.761441 -73.977625
#
#                                              category
# 0        [{'alias': 'bakeries', 'title': 'Bakeries'}]
# 1   [{'alias': 'delis', 'title': 'Delis'}, {'alias...
# 2              [{'alias': 'ramen', 'title': 'Ramen'}]
# 3   [{'alias': 'foodstands', 'title': 'Food Stands...
# 4   [{'alias': 'artmuseums', 'title': 'Art Museums'}]
# 5              [{'alias': 'parks', 'title': 'Parks'}]
# 6   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
# 7              [{'alias': 'tacos', 'title': 'Tacos'}]
# 8   [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 9   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...
# 10  [{'alias': 'bagels', 'title': 'Bagels'}, {'ali...
# 11  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 12  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 13  [{'alias': 'newamerican', 'title': 'American (...
# 14             [{'alias': 'parks', 'title': 'Parks'}]
# 15       [{'alias': 'steak', 'title': 'Steakhouses'}]
# 16  [{'alias': 'donuts', 'title': 'Donuts'}, {'ali...
# 17         [{'alias': 'museums', 'title': 'Museums'}]
# 18  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 19  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...
# 20             [{'alias': 'tacos', 'title': 'Tacos'}]
# 21  [{'alias': 'french', 'title': 'French'}, {'ali...
# 22  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 23  [{'alias': 'icecream', 'title': 'Ice Cream & F...
# 24  [{'alias': 'landmarks', 'title': 'Landmarks & ...
# 25  [{'alias': 'comfortfood', 'title': 'Comfort Fo...
# 26             [{'alias': 'pizza', 'title': 'Pizza'}]
# 27  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...
# 28  [{'alias': 'french', 'title': 'French'}, {'ali...
# 29  [{'alias': 'shanghainese', 'title': 'Shanghain...
# 30       [{'alias': 'steak', 'title': 'Steakhouses'}]
# 31  [{'alias': 'bagels', 'title': 'Bagels'}, {'ali...
# 32  [{'alias': 'italian', 'title': 'Italian'}, {'a...
# 33  [{'alias': 'icecream', 'title': 'Ice Cream & F...
# 34  [{'alias': 'korean', 'title': 'Korean'}, {'ali...
# 35             [{'alias': 'ramen', 'title': 'Ramen'}]
# 36  [{'alias': 'newamerican', 'title': 'American (...
# 37  [{'alias': 'desserts', 'title': 'Desserts'}, {...
# 38             [{'alias': 'pizza', 'title': 'Pizza'}]
# 39  [{'alias': 'steak', 'title': 'Steakhouses'}, {...
# 40         [{'alias': 'seafood', 'title': 'Seafood'}]
# 41  [{'alias': 'landmarks', 'title': 'Landmarks & ...
# 42  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 43  [{'alias': 'italian', 'title': 'Italian'}, {'a...
# 44  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 45       [{'alias': 'desserts', 'title': 'Desserts'}]
# 46  [{'alias': 'breakfast_brunch', 'title': 'Break...
# 47  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 48  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 49  [{'alias': 'artmuseums', 'title': 'Art Museums'}]

# %%
        name, rating, review_count,categories,address, latitude, longitude = [], [], [], [], [],[],[] 
        for b in  globals()['businesses%s' % ]:
            name.append(b['name'])
            rating.append(b['rating'])
            address.append(b['location']['display_address'])
            latitude.append(b['coordinates']['latitude'])
            longitude.append(b['coordinates']['longitude'])
            review_count.append(b['review_count'])
            categories.append(b['categories'])
            
        globals()['df%s' % i] = pd.DataFrame()
        globals()['df%s' % i]['name'] = name
        globals()['df%s' % i]['rating'] = rating
        globals()['df%s' % i]['review_count'] = review_count
        globals()['df%s' % i]['address'] = address
        globals()['df%s' % i]['latitude'] = latitude
        globals()['df%s' % i]['longitude'] = longitude
        globals()['df%s'%i]['category']= categories

# %%
frames = []
for i in range(1,21):
    frames.append(globals()['df%s' % i])

result = pd.concat(frames)

# %%
result.to_csv('../output/1000Ramen11_26.csv')

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params21 = {'location':"New York City",'categories':'Ramen', "offset": '1000','limit':"50"}
req21 = requests.get(url, params = params21, headers = headers)
reqs21 = json.loads(req21.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params22 = {'location':"New York City",'categories':'Ramen', "offset": '1050','limit':"50"}
req22 = requests.get(url, params = params22, headers = headers)
reqs22 = json.loads(req22.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params23 = {'location':"New York City",'categories':'Ramen', "offset": '1100','limit':"50"}
req23 = requests.get(url, params = params23, headers = headers)
reqs23 = json.loads(req23.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params24 = {'location':"New York City",'categories':'Ramen', "offset": '1150','limit':"50"}
req24 = requests.get(url, params = params24, headers = headers)
reqs24 = json.loads(req24.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params25 = {'location':"New York City",'categories':'Ramen', "offset": '1200','limit':"50"}
req25 = requests.get(url, params = params25, headers = headers)
reqs25 = json.loads(req25.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params26 = {'location':"New York City",'categories':'Ramen', "offset": '1250','limit':"50"}
req26 = requests.get(url, params = params26, headers = headers)
reqs26 = json.loads(req26.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params27 = {'location':"New York City",'categories':'Ramen', "offset": '1300','limit':"50"}
req27 = requests.get(url, params = params27, headers = headers)
reqs27 = json.loads(req27.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params28 = {'location':"New York City",'categories':'Ramen', "offset": '1350','limit':"50"}
req28 = requests.get(url, params = params28, headers = headers)
reqs28 = json.loads(req28.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params29 = {'location':"New York City",'categories':'Ramen', "offset": '1400','limit':"50"}
req29 = requests.get(url, params = params29, headers = headers)
reqs29 = json.loads(req29.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params30 = {'location':"New York City",'categories':'Ramen', "offset": '1450','limit':"50"}
req30 = requests.get(url, params = params30, headers = headers)
reqs30 = json.loads(req30.text)

# %%
parsed1 = json.loads(req1.text)
parsed2 = json.loads(req2.text)
parsed3 = json.loads(req3.text)
parsed4 = json.loads(req4.text)
parsed5 = json.loads(req5.text)
parsed6 = json.loads(req6.text)
parsed7 = json.loads(req7.text)
parsed8 = json.loads(req8.text)
parsed9 = json.loads(req9.text)
parsed10 = json.loads(req10.text)

# %%
parsed11 = json.loads(req11.text)
parsed12 = json.loads(req12.text)
parsed13 = json.loads(req13.text)
parsed14 = json.loads(req14.text)
parsed15 = json.loads(req15.text)
parsed16 = json.loads(req16.text)
parsed17 = json.loads(req17.text)
parsed18 = json.loads(req18.text)
parsed19 = json.loads(req19.text)
parsed20 = json.loads(req20.text)

# %%
parsed21 = json.loads(req21.text)
parsed22 = json.loads(req22.text)
parsed23 = json.loads(req23.text)
parsed24 = json.loads(req24.text)
parsed25 = json.loads(req25.text)
parsed26 = json.loads(req26.text)
parsed27 = json.loads(req27.text)
parsed28 = json.loads(req28.text)
parsed29 = json.loads(req29.text)
parsed30 = json.loads(req30.text)

# %%
parsed31 = json.loads(req31.text)
parsed32 = json.loads(req32.text)
parsed33 = json.loads(req33.text)
parsed34 = json.loads(req34.text)
parsed35 = json.loads(req35.text)
parsed36 = json.loads(req36.text)
parsed37 = json.loads(req37.text)
parsed38 = json.loads(req38.text)
parsed39 = json.loads(req39.text)
parsed40 = json.loads(req40.text)

# %%
parsed41 = json.loads(req41.text)
parsed42 = json.loads(req42.text)
parsed43 = json.loads(req43.text)
parsed44 = json.loads(req44.text)
parsed45 = json.loads(req45.text)
parsed46 = json.loads(req46.text)
parsed47 = json.loads(req47.text)
parsed48 = json.loads(req48.text)
parsed49 = json.loads(req49.text)
parsed50 = json.loads(req50.text)

# %%
businesses1 = parsed1["businesses"]
businesses2 = parsed2["businesses"]
businesses3 = parsed3["businesses"]
businesses4 = parsed4["businesses"]
businesses5 = parsed5["businesses"]
businesses6 = parsed6["businesses"]
businesses7 = parsed7["businesses"]
businesses8 = parsed8["businesses"]
businesses9 = parsed9["businesses"]
businesses10 = parsed10["businesses"]

# %%
businesses11 = parsed11["businesses"]
businesses12 = parsed12["businesses"]
businesses13 = parsed13["businesses"]
businesses14 = parsed14["businesses"]
businesses15 = parsed15["businesses"]
businesses16 = parsed16["businesses"]
businesses17 = parsed17["businesses"]
businesses18 = parsed18["businesses"]
businesses19 = parsed19["businesses"]
businesses20 = parsed20["businesses"]

# %%
businesses21 = parsed21["businesses"]
businesses22 = parsed22["businesses"]
businesses23 = parsed23["businesses"]
businesses24 = parsed24["businesses"]
businesses25 = parsed25["businesses"]
businesses26 = parsed26["businesses"]
businesses27 = parsed27["businesses"]
businesses28 = parsed28["businesses"]
businesses29 = parsed29["businesses"]
businesses30 = parsed30["businesses"]

# %%
parsed1["businesses"]

# %%
print(businesses1[0]['price'])
print(businesses1[6]['price'])

# %%
name, review_count, rating, address, latitude, longitude = [], [], [], [], [],[]

for b in businesses1:
    name.append(b['name'])
    rating.append(b['rating'])
    address.append(b['location']['display_address'])
    latitude.append(b['coordinates']['latitude'])
    longitude.append(b['coordinates']['longitude'])
    review_count.append(b['review_count'])


df1 = pd.DataFrame()
df1['name'] = name
df1['rating'] = rating
df1['review_count'] = review_count
df1['address'] = address
df1['latitude'] = latitude
df1['longitude'] = longitude

# %%
name, rating, address, latitude, longitude = [], [], [], [], [] 

for b in businesses2:
    name.append(b['name'])
    rating.append(b['rating'])
    address.append(b['location']['display_address'])
    latitude.append(b['coordinates']['latitude'])
    longitude.append(b['coordinates']['longitude'])
    review_count.append(b['review_count'])



df2 = pd.DataFrame()
df2['name'] = name
df2['rating'] = rating
df2['address'] = address
df2['latitude'] = latitude
df2['longitude'] = longitude

# %%
name, rating, address, latitude, longitude = [], [], [], [], [] 

for b in businesses3:
    name.append(b['name'])
    rating.append(b['rating'])
    address.append(b['location']['display_address'])
    latitude.append(b['coordinates']['latitude'])
    longitude.append(b['coordinates']['longitude'])
    review_count.append(b['review_count'])



df3 = pd.DataFrame()
df3['name'] = name
df3['rating'] = rating
df3['address'] = address
df3['latitude'] = latitude
df3['longitude'] = longitude

# %%
name, rating, address, latitude, longitude = [], [], [], [], [] 

for b in businesses4:
    name.append(b['name'])
    rating.append(b['rating'])
    address.append(b['location']['display_address'])
    latitude.append(b['coordinates']['latitude'])
    longitude.append(b['coordinates']['longitude'])
    review_count.append(b['review_count'])



df4 = pd.DataFrame()
df4['name'] = name
df4['rating'] = rating
df4['address'] = address
df4['latitude'] = latitude
df4['longitude'] = longitude

# %%
name, rating, address, latitude, longitude = [], [], [], [], [] 

for b in businesses5:
    name.append(b['name'])
    rating.append(b['rating'])
    address.append(b['location']['display_address'])
    latitude.append(b['coordinates']['latitude'])
    longitude.append(b['coordinates']['longitude'])
    review_count.append(b['review_count'])


df5 = pd.DataFrame()
df5['name'] = name
df5['rating'] = rating
df5['address'] = address
df5['latitude'] = latitude
df5['longitude'] = longitude

# %%
name, rating, address, latitude, longitude = [], [], [], [], [] 

for b in businesses6:
    name.append(b['name'])
    rating.append(b['rating'])
    address.append(b['location']['display_address'])
    latitude.append(b['coordinates']['latitude'])
    longitude.append(b['coordinates']['longitude'])
    review_count.append(b['review_count'])


df6 = pd.DataFrame()
df6['name'] = name
df6['rating'] = rating
df6['address'] = address
df6['latitude'] = latitude
df6['longitude'] = longitude

# %%
name, rating, address, latitude, longitude = [], [], [], [], [] 

for b in businesses7:
    name.append(b['name'])
    rating.append(b['rating'])
    address.append(b['location']['display_address'])
    latitude.append(b['coordinates']['latitude'])
    longitude.append(b['coordinates']['longitude'])
    review_count.append(b['review_count'])


df7 = pd.DataFrame()
df7['name'] = name
df7['rating'] = rating
df7['address'] = address
df7['latitude'] = latitude
df7['longitude'] = longitude

# %%
name, rating, address, latitude, longitude = [], [], [], [], [] 

for b in businesses8:
    name.append(b['name'])
    rating.append(b['rating'])
    address.append(b['location']['display_address'])
    latitude.append(b['coordinates']['latitude'])
    longitude.append(b['coordinates']['longitude'])
    review_count.append(b['review_count'])


df8 = pd.DataFrame()
df8['name'] = name
df8['rating'] = rating
df8['address'] = address
df8['latitude'] = latitude
df8['longitude'] = longitude

# %%
name, rating, address, latitude, longitude = [], [], [], [], [] 

for b in businesses9:
    name.append(b['name'])
    rating.append(b['rating'])
    address.append(b['location']['display_address'])
    latitude.append(b['coordinates']['latitude'])
    longitude.append(b['coordinates']['longitude'])
    review_count.append(b['review_count'])


df9 = pd.DataFrame()
df9['name'] = name
df9['rating'] = rating
df9['address'] = address
df9['latitude'] = latitude
df9['longitude'] = longitude

# %%
name, rating, address, latitude, longitude = [], [], [], [], [] 

for b in businesses10:
    name.append(b['name'])
    rating.append(b['rating'])
    address.append(b['location']['display_address'])
    latitude.append(b['coordinates']['latitude'])
    longitude.append(b['coordinates']['longitude'])
    review_count.append(b['review_count'])


df10 = pd.DataFrame()
df10['name'] = name
df10['rating'] = rating
df10['address'] = address
df10['latitude'] = latitude
df10['longitude'] = longitude

# %%
result.to_csv('../output/1500Ramen.csv')

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params4 = {'location':"New York City",'categories':'Ramen', "offset": '1050','limit':"50"}
req4 = requests.get(url, params = params4, headers = headers)
reqs4 = json.loads(req4.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params4 = {'location':"New York City",'categories':'Ramen', "offset": '1150','limit':"50"}
req4 = requests.get(url, params = params4, headers = headers)
reqs4 = json.loads(req4.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params4 = {'location':"New York City",'categories':'Ramen', "offset": '1250','limit':"50"}
req4 = requests.get(url, params = params4, headers = headers)
reqs4 = json.loads(req4.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params4 = {'location':"New York City",'categories':'Ramen', "offset": '1350','limit':"50"}
req4 = requests.get(url, params = params4, headers = headers)
reqs4 = json.loads(req4.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params4 = {'location':"New York City",'categories':'Ramen', "offset": '1450','limit':"50"}
req4 = requests.get(url, params = params4, headers = headers)
reqs4 = json.loads(req4.text)

# %%
api_key = '3smzQBF0JGHnhSZWyzDIKxy2S6DKk9C0tPx_J7Cohgwc6Hjp5g_g8SycTy3Ani74c0EPQ9d2QlJqooZ4EEfXNtxlD6TBJFvD4Vri4Mc9iUBnoIookKggwnMQrBexX3Yx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params4 = {'location':"New York City",'categories':'Ramen', "offset": '1500','limit':"50"}
req4 = requests.get(url, params = params4, headers = headers)
reqs4 = json.loads(req4.text)
